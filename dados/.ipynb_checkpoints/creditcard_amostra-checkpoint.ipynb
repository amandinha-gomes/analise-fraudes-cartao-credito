# %%
import pandas as pd

df = pd.read_csv("dados/credit_card_transactions.csv")

# Amostra de 50 mil linhas 
df_sample = df.sample(50000, random_state=42)

df_sample.to_csv(
    "dados/credit_card_transactions_sample.csv",
    index=False
)
